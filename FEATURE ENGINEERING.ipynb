# %% [markdown]
# # FEATURE ENGINEERING.
# ### 1. Feature Importances.
# ### 2. Scaling.

# %%
import pandas as pd
import seaborn as sb
data = pd.read_csv('breast_cancer.csv')
data.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
data.corr()
# Out:
#                          Unnamed: 0  mean radius  mean texture  \
# Unnamed: 0                 1.000000    -0.092895      0.066624
# mean radius               -0.092895     1.000000      0.323782
# mean texture               0.066624     0.323782      1.000000
# mean perimeter            -0.099700     0.997855      0.329533
# mean area                 -0.082966     0.987357      0.321086
# mean smoothness           -0.169402     0.170581     -0.023389
# mean compactness          -0.162487     0.506124      0.236702
# mean concavity            -0.165151     0.676764      0.302418
# mean concave points       -0.174718     0.822529      0.293464
# mean symmetry             -0.192960     0.147741      0.071401
# mean fractal dimension    -0.071802    -0.311631     -0.076437
# radius error              -0.126542     0.679090      0.275869
# texture error              0.046544    -0.097317      0.386358
# perimeter error           -0.115966     0.674172      0.281673
# ...

# %%
sb.heatmap(data.corr())

# %%
data.corr().outcome.sort_values(ascending=False) # selecting only positive correlation values & rejecting the negative correlation values.
# its part of feature engineering
# Out:
# outcome                    1.000000
# Unnamed: 0                 0.283615
# smoothness error           0.067016
# mean fractal dimension     0.012838
# texture error              0.008303
# symmetry error             0.006522
# fractal dimension error   -0.077972
# concavity error           -0.253730
# compactness error         -0.292999
# worst fractal dimension   -0.323872
# mean symmetry             -0.330499
# mean smoothness           -0.358560
# concave points error      -0.408042
# mean texture              -0.415185
# worst symmetry            -0.416294
# worst smoothness          -0.421465
# worst texture             -0.456903
# area error                -0.548236
# perimeter error           -0.556141
# radius error              -0.567134
# worst compactness         -0.590998
# mean compactness          -0.596534
# worst concavity           -0.659610
# mean concavity            -0.696360
# mean area                 -0.708984
# mean radius               -0.730029
# ...

# %%
X=data.iloc[:,:-1]
y=data.outcome

# %%
X.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10)

# %%
model.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
model.feature_importances_
# Out:
# array([0.00904602, 0.06643864, 0.01305433, 0.07219789, 0.00265096,
#        0.00594556, 0.00455272, 0.00430387, 0.15088483, 0.00518449,
#        0.00210228, 0.05200877, 0.00143543, 0.00424361, 0.01274259,
#        0.00128534, 0.00333825, 0.00781961, 0.00993298, 0.0003351 ,
#        0.00231123, 0.09813624, 0.01170009, 0.15776096, 0.01593529,
#        0.01184614, 0.00899337, 0.02863068, 0.22727788, 0.00475312,
#        0.00315171])

# %%
pd.DataFrame(model.feature_importances_,index= X.columns).sort_values(0,ascending=False)
# feature importance it give % value of contribution of feature(columns) to the model & we can reject those lesser % value of non-contributing columns.
# Out:
#                                 0
# worst concave points     0.227278
# worst perimeter          0.157761
# mean concave points      0.150885
# worst radius             0.098136
# mean perimeter           0.072198
# mean radius              0.066439
# radius error             0.052009
# worst concavity          0.028631
# worst area               0.015935
# mean texture             0.013054
# area error               0.012743
# worst smoothness         0.011846
# worst texture            0.011700
# concave points error     0.009933
# Unnamed: 0               0.009046
# worst compactness        0.008993
# concavity error          0.007820
# mean smoothness          0.005946
# mean symmetry            0.005184
# worst symmetry           0.004753
# mean compactness         0.004553
# mean concavity           0.004304
# perimeter error          0.004244
# compactness error        0.003338
# worst fractal dimension  0.003152
# mean area                0.002651
# ...

# %%
X.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
from sklearn.preprocessing import scale
pd.DataFrame(scale(X), columns=X.columns)
# Out:
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0     -1.729009     1.097064     -2.073335        1.269934   0.984375
# 1     -1.722921     1.829821     -0.353632        1.685955   1.908708
# 2     -1.716833     1.579888      0.456187        1.566503   1.558884
# 3     -1.710745    -0.768909      0.253732       -0.592687  -0.764464
# 4     -1.704657     1.750297     -1.151816        1.776573   1.826229
# ..          ...          ...           ...             ...        ...
# 564    1.704657     2.110995      0.721473        2.060786   2.343856
# 565    1.710745     1.704854      2.085134        1.615931   1.723842
# 566    1.716833     0.702284      2.045574        0.672676   0.577953
# 567    1.722921     1.838341      2.336457        1.982524   1.735218
# 568    1.729009    -1.808401      1.221792       -1.814389  -1.347789
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# ...
